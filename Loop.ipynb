# %%
#1 Desenvolva o gerador de tabuada, sem olhar o realizado em aula.

numero = int(input('Para qual numero voce gostaria que calculassemos uma tabuada? '))

for i in range (1,11):
  print(f'{numero} X {i} = {numero * i}')



#2 Faça um programa que, dado um conjunto de N números, determine o menor valor, o maior valor e a soma dos valores.

#solucao1
N = int(input('Quantos numeros voce gostaria que nos gerassemos? '))

num = float(input('Digite o 1a. numero '))
menor = num
maior = num
sum = num

for i in range(2, N+1):
  num2 = float(input(f'Digite o {i}o. numero '))
  if num2 < menor:
    menor = num2
  elif num2 > maior: 
    maior = num2
  sum += num2

print(f'O menor numero e {menor}. O maior numero e {maior}. A soma de todos os numeros e {sum}.')
 
#solucao2

N = int(input('Quantos numeros voce gostaria que nos gerassemos? '))
menor = 0
maior = 0
sum = 0

for i in range(1, N+1):
  if i == 1:
    num = float(input(f'Digite o {i}o. numero '))
    menor = num
    maior = num
    sum = num
  else:
    num = float(input(f'Digite o {i}o. numero '))
    if num < menor:
      menor = num
    elif num > maior: 
      maior = num
    sum += num

print(f'O menor numero e {menor}. O maior numero e {maior}. A soma de todos os numeros e {sum}.')


#3 Faça um programa que peça para n pessoas a sua idade, ao final o programa devera verificar se a média de idade da turma varia entre 0 e 25,26 e 60 e maior que 60; e então, dizer se a turma é jovem, adulta ou idosa, conforme a média calculada.

n = int(input('Quantas pessoas participarao? '))
soma_idade=0

for i in range(n):
  idade = float(input(f'Digite a idade da pessoa numero {i+1}. '))
  soma_idade += idade
media = soma_idade / n
print(f'A media de idade da turma e {media}')
if media > 60:
  print('A turma e idosa')
elif media >=26:
  print('A turma e adulta')
else:
  print('A turma e jovem')
  


#4 O Departamento Estadual de Meteorologia lhe contratou para desenvolver um programa que leia  um conjunto x de temperaturas, e informe ao final a menor e a maior temperaturas informadas, bem como a média das temperaturas.

x = int(input('Digite quantas temperatureas seram estudadas nesse programa: '))
menor = 10000000
maior = -10000000
sum_temp = 0

for i in range(x):
  temp = int(input('Qual a {i+1}a temperatura? '))
  if temp < menor:
    menor = temp
  elif temp > maior:
    maior = temp




#5 Faça um programa que leia uma quantidade indeterminada de números positivos e conte quantos deles estão nos seguintes intervalos: [0-25], [26-50], [51-75] e [76-100]. A entrada de dados deverá terminar quando for lido um número negativo.

N = int(input('Quantos numeros voce deseja processar? '))
count1=0
count2=0
count3=0
count4=0


for i in range(N):
  num = int(input(f'Digite o {i+1} numero '))
  if num < 0:
    print('O numero digitado e negativo e o programa sera terminado.')
    break
  elif num >= 76 and num <= 100:
    count1 += 1
  elif num >= 51:
    count2 += 1
  elif num >= 26:
    count3 += 1
  else:
    count4 +=1

print(f'''Abaixo temos a quantidade de pessoas com idades validas dividos em diferentes intervalos: 
[0-25] = {count4}
[26-50] = {count3}
[51-75] = {count2}
[76-100] = {count1}''')
