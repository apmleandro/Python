# %%
# A Calabouço Discos é uma loja de vinis que resiste ao digital com albuns clássicos de lendas do rock. Os albuns são catalogados por: id, ano, artista, genero, titulo, preço. Os clientes são armazenados com: id, nome e idade. E as vendas da loja são armazenadas da seguinte maneira: id, id_cliente, ids_albuns (que é uma lista de IDs com os albuns que a pessoa comprou), total_da_venda.

# Utilizando dicionários, crie um código para registrar as vendas e ao final apresentar o fechamento do dia, apresentando as vendas uma a uma.

# Plus1: Quantas vendas foram realizadas?
# Plus2: Qual foi o faturamento total da loja?
# Plus3: Qual cliente mais gastou?
# Plus4: Qual foi a maior compra?
# Plus5: Qual é o album mais vendido?
# Plus6: Quais sao os generos mais comprados pelas faixas de idade abaixo:
  # - 18 a 25 anos
  # - 25 a 35 anos
  # - 35 a 55 anos
  # - acima de 55 anos

#Solution version 2 - Versao final com json

import json
import string
import secrets

#create / open json file - need to enter as I am doing something (?)
# with open('inventory.json',"w") as a:
#   json.dump({'Artist' : {} },a,indent = 4)
# with open('purchase_record.json',"w") as a:
#   json.dump({'Purchase Record': {} },a,indent = 4)

def new_record_store():
  singer = input('Artist name: ').lower()
  album  = input('Album: ').lower()
  year   = input('Year launched: ').lower()
  while True:
    try:
      qtd    = int(input('Number of albums: '))
      price  = float(input('Price: '))
      genre_type = int(input('''Genre:
      Classic Rock [1]
      Blues        [2]
      MPB          [3]
              '''))
      if   genre_type == 1:
        genre = 'Classic Rock'
        break
      elif genre_type == 2:
        genre = 'Blues'
        break
      elif genre_type == 3:
        genre = 'MPB'
        break
      else:
        print('Invalid Option')          
        continue
    except:
      print('Invalid Option')
      continue
  new_album = [{"Album":album , "Year": year, "QTD":qtd, "Price":price, "Genre": genre}]
  print('Inventory sucesfully updated')
  return new_album,singer

  
def close_cashier_store():
  close = input('Are you sure you want to close the Cashier? [y/n]')
  if   close == 'n':
    print('We are taking you back to Admin Menu')
    admin_menu_store()
  elif close == 'y': 
    print('A closing report is being wrapped up. This might take a few seconds.')
    print('----------Report-----------')
    print('------Purchase Record------')
    purchase_report()
    highest_total_purchase()
    age_genre_purchase()
    print('Thank you for working with us. See you later!')
    
  else:
    print('Invalid Option')
    close_cashier_store()


def purchase_report():
  with open('purchase_record.json') as archive:
    purchase = json.load(archive)
  for k,v in purchase.items():
    for k_purchase,v_purchase in v.items():
      r = v_purchase["Record Purchased"]
      c = v_purchase["Customer_info"]
      print(f'Purchase Id: {k_purchase}')
      print(f'''
      Customer information:
      Name      : {c["Customer"]}
      Phone     : {c["Phone"]}
      Age Group : {c["age_group"]}
      Adress    : {c["address"]}
      ''')
      for i in range(len(r)):
        print(f'''
      Record Purchased:
      Artist    :{r[i]["Artist"]}
      Album     :{r[i]["Album"]}
      Year      :{r[i]["Year"]}
      Price     :{r[i]["Price"]}
      Quantity  :{r[i]["QTD"]}
      ''')
    
def inventory_store():
  new,singer = new_record_store()
  with open('inventory.json', 'r') as a:
    current = json.load(a)
    for k,v in current.items():
      if singer in v.keys():
        v[singer].append(new[0])
        with open('inventory.json','w') as b:
          json.dump(current, b, indent =4)
      else:
        current["Artist"][singer] = new
        with open('inventory.json','w') as b:
          json.dump(current, b, indent =4)
  while True:
    print('Add new album        [1]')
    print('Return to Admin Menu [2]')
    print('Return to Main  Menu [3]')
    option = input()
    if   option == '1':
      inventory_store()
      break
    elif option == '2':
      admin_menu_store()
      break
    elif option == '3':
      main_menu()
      break
    else:
      print('Invalid Option')
      continue
        
      
def search_genre_record():
    genre_option = input('''Genre:
    [1] Classic Rock
    [2] Blues
    [3] MPB
            ''')
    match genre_option:
      case "1":
        genre = "Classic Rock"
        search_search_genre(genre)
      case "2":
        genre = "Blues"
        search_search_genre(genre)
      case "3":
        genre = "MPB"
        search_search_genre(genre)
      case _:
        print('Invalid Option')
        search_genre_record()

def search_search_genre(genre):
  with open('inventory.json') as archive:
    current = json.load(archive)
    for k,v in current.items():
          for k_artist,v_artist in v.items():
              for i in range(len(v_artist)):
                a = v_artist[i]["Genre"]
                if genre in a:
                  artist = k_artist
                  album = v_artist[i]["Album"]
                  year  = v_artist[i]["Year"]
                  stock = v_artist[i]["QTD"]
                  price = v_artist[i]["Price"]
                  genre = v_artist[i]["Genre"]
                  
                  print(f'''Artist : {artist}
                  Album : {album}
                  Year  : {year}
                  Amount in Stock : {stock}
                  Price : ${price}
                  Genre : {genre}
                 ''')
               
  while True:
    option = input('''                  -------------MENU-------------
    Purchase Album        [1]
    Return Main Menu      [2]
    Search Other Genre    [3]
    ''')
    if option == '1':
      search_album_record()
    elif option == '2':
      main_menu()
    elif option == '3':
      search_genre_record()
    else:
      print('Invalid Option')
      continue

def search_artist_record():
  artist = input('Artist: ')
  found = False
  with open('inventory.json') as archive:
    current = json.load(archive)
    for v in current.values():
      for v_artist in v.keys():
        if v_artist == artist:
          for i in range(len(v[artist])):
            print(f''' Artist : {artist}
              Album : {v[artist][i]["Album"]}
              Year  : {v[artist][i]["Year"]}
              Amount in Stock : {v[artist][i]["QTD"]}
              Price : ${v[artist][i]["Price"]}
              Genre : {v[artist][i]["Genre"]}
           ''')
          found = True
          option = input('''                  --------MENU--------
                  Purchase Album   [1]
                  Return Main Menu [2]
                  ''')
          if option == '1':
            search_album_record()
          if option == '2':
            main_menu()
  if not found:
    print('Artist Not Found')
    option = input('''    -----------MENU-----------
    Search Other Artist   [1]
    Return Main Menu      [2]
    ''')
    if option == '1':
      search_artist_record()
    if option == '2':
      main_menu()        

def search_album_record():
  album = input('Album: ')
  found= False
  with open('inventory.json') as archive:
    current = json.load(archive)
    for k,v in current.items():
          for k_artist,v_artist in v.items():
              for i in range(len(v_artist)):
                a = v_artist[i]["Album"]
                if album in a:
                  artist = k_artist
                  album = v_artist[i]["Album"]
                  year  = v_artist[i]["Year"]
                  stock = v_artist[i]["QTD"]
                  price = v_artist[i]["Price"]
                  genre = v_artist[i]["Genre"]
                  
                  print(f'''Artist : {artist}
                  Album : {album}
                  Year  : {year}
                  Amount in Stock : {stock}
                  Price : ${price}
                  Genre : {genre}
                 ''')
                  found = True
                  option = input('''                  -------------MENU-------------
                  Purchase this Album   [1]
                  Return Main Menu      [2]
                  ''')
                  if option == '1':
                    purchase_record(artist, album, year, stock, price, genre)
                  if option == '2':
                    main_menu()
  if not found:
    print('Album Not Found')
    option = input('''    ----------MENU----------
    Search Other ALbum   [1]
    Return Main Menu     [2]
    ''')
    if option == '1':
      search_album_record()
    if option == '2':
      main_menu()            

def search_record():
  type = input('''Search Record by:
[1] Genre
[2] Artist
[3] Album
''')
  if   type == '1':
    search_genre_record()
  elif type == '2':
    search_artist_record()
  elif type == '3':
    search_album_record()
  else:
    print('Invalid 3')
    search_record()
  
def purchase_record(artist, album, year, stock, price, genre):
  if stock == 0:
    print('Sorry, we are out of stock. Please come back later!')
    print('We are returning you to the Main Menu. See you later!')
    print('''
    .
    .
    .''')
    main_menu()
  try:
    amount = int(input('Quantity: '))
    if amount > stock:
      print('Not enough albums in-stock. Please try another amount')
      purchase_record(artist, album, year, stock, price, genre)
  except:
    print('Invalid quantity')
    purchase_record(artist, album, year, stock, price, genre)
    
  print('Before proceeding with the purchase, please enter your personal information below:')
  name    = input('Name: ')
  address = input('Address: ')
  phone   = input('Phone Number: ')
  while True:
    try:
      birth   = int(input('Birthday Year: '))
      break
    except:
      print('Invalid Birth Year')
      continue
  print('Thank you for providing your information.')
  print('Please wait couples seconds while we process your purchase.')

  #Calculate age group
  age = 2023 - birth
  if age < 18:
    print('We are unable to process your payment. Only adults with age >= 18 are allowed to purchase a record in this store. Please have an adult to purchase this album.')
    main_menu()

  elif age > 55:
    age_group = "55+"
  elif age  >= 35:
    age_group = "35-55"
  elif age  >= 25:
    age_group = "25-35"
  elif age  >=  18:
    age_group = "18-25"

  #create purchase ID recipe:
  alphabet = string.ascii_letters + string.digits
  while True:
      purchase_ID = ''.join(secrets.choice(alphabet) for i in range(10))
      if (any(c.islower() for c in purchase_ID)
              and any(c.isupper() for c in purchase_ID)
              and sum(c.isdigit() for c in purchase_ID) >= 3):
          break
  
  with open('purchase_record.json') as archive:
    current = json.load(archive)
    for k,v in current.items():
      v[purchase_ID] = {"Customer_info":{"Customer":name,"Phone": phone,"age_group": age_group,"address":address}, "Record Purchased": [{"Artist":artist,"Album":album , "Year": year, "Price":price, "Genre": genre, "QTD":amount}]}

  with open('purchase_record.json', "w") as a:
    json.dump(current,a,indent=4)

  #update stock
  with open('inventory.json', 'r')  as b:
    current = json.load(b)
    for k2, v2 in current.items():
      for k_stock,v_stock in v2.items():
        for i in range(len(v_stock)):
          if v_stock[i]["Album"] == album:
              v_stock[i]["QTD"] -= amount 
                
  with open('inventory.json', "w") as c:
    json.dump(current,c,indent=4)
    
  print('Purchase completed succesfully')
  print('We are returning you to the Main Menu. See you later!')
  print('''
  .
  .
  .''')
  main_menu()
  
def delete_record_store():
  album = input('Album Name: ')
  cond = False
  with open('inventory.json') as archive:
    current = json.load(archive)
    for k,v in current.items():
          for k_artist,v_artist in v.items():
              for i in range(len(v_artist)):
                a = v_artist[i]["Album"]
                if album in a:
                  artist = k_artist
                  album = v_artist[i]["Album"]
                  year  = v_artist[i]["Year"]
                  stock = v_artist[i]["QTD"]
                  price = v_artist[i]["Price"]
                  genre = v_artist[i]["Genre"]
                  
                  print(f'''Artist : {artist}
                  Album : {album}
                  Year  : {year}
                  Amount in Stock : {stock}
                  Price : ${price}
                  Genre : {genre}
                 ''')
                  cond = True
                  option = input('''                  -------------MENU-------------
                  Delete this Album   [1]
                  Return Admin Menu   [2]
                  ''')
                  if option == '1':
                    removed_record = v_artist.pop(i)
                    print(f'Record Deleted from inventory: {removed_record}')
                    print('We are returning you to the Admin Menu. See you later!')
                    print('''
                    .
                    .
                    .''')
                    admin_menu_store()
                  if option == '2':
                    admin_menu_store()

  with open('inventory.json',"w") as b:
    json.dump(current,b,indent=4)
    
  if not cond:
    print('Album not found')
    option = input('''    ----------MENU----------
    Search Other ALbum   [1]
    Return Admin Menu    [2]
    ''')
    if option == '1':
      delete_record_store()
    if option == '2':
      admin_menu_store()           
    

def age_genre_purchase():
  age_18_25 = []
  age_25_35 = []
  age_35_55 = []
  age_55_plus = []
  with open('purchase_record.json') as archive:
    purchase = json.load(archive)
  for k,v in purchase.items():
    for k_purchase,v_purchase in v.items():
      for i in range(len(v_purchase["Record Purchased"])):
        if   v_purchase["Customer_info"]["age_group"] == "55+":
          age_55_plus.append(v_purchase["Record Purchased"][i]["Genre"])
        elif v_purchase["Customer_info"]["age_group"] == "18-25":
          age_18_25.append(v_purchase["Record Purchased"][i]["Genre"])
        elif v_purchase["Customer_info"]["age_group"] == "25-35":
          age_25_35.append(v_purchase["Record Purchased"][i]["Genre"])
        elif v_purchase["Customer_info"]["age_group"] == "35-55":
          age_35_55.append(v_purchase["Record Purchased"][i]["Genre"])

  print('Genre most purchased per age group:')
  try:
    a = most_frequent(age_18_25)
    print(f'[18-25] : {a}')
  except:
    print('[18-25] : No purchase was made by this age group today')
  try:
    b = most_frequent(age_25_35)
    print(f'[25-35] : {b}')
  except:
    print('[25-35] : No purchase was made by this age group today')
  try:
    c = most_frequent(age_35_55)
    print(f'[35-55] : {c}')
  except:
    print('[35-55] : No purchase was made by this age group today')
  try:
    d = most_frequent(age_55_plus)
    print(f'["55+]  : {d}')
  except:
    print('["55+] : No purchase was made by this age group today')
  
def most_frequent(List):
    return max(set(List), key = List.count)

def highest_total_purchase():
  purchase_client = {}
  with open('purchase_record.json') as archive:
    purchase = json.load(archive)
  for k,v in purchase.items():
    for k_purchase,v_purchase in v.items():
      r = v_purchase["Record Purchased"]
      for i in range(len(r)):
        suma = 0
        suma += r[i]["Price"]*r[i]["QTD"]
        # print(f'{v_purchase["Customer_info"]["Customer"]} : ${suma}USD')
        purchase_client.update({v_purchase["Customer_info"]["Customer"] : suma})
  client_highest  = max(purchase_client, key=purchase_client.get)
  purchase_amount = purchase_client[client_highest]
  print(f'''Highest Purchase of the day:
Customer   : {client_highest}
Money Spent: {purchase_amount}USD
  ''')
  total_influx    = list(purchase_client.values())
  print(f'Total Amount of sales of the day: {len(v)} sales')
  print(f'Total Cash Influx of the day    : ${sum(total_influx)}USD')

  
def most_sold_record():
  purchase_album = {}
  with open('purchase_record.json') as archive:
    purchase = json.load(archive)
  for k,v in purchase.items():
    for k_purchase,v_purchase in v.items():
      r = v_purchase["Record Purchased"]
      for i in range(len(r)):
        if r[i]["Album"] in purchase_album.keys():
          purchase_album[r[i]["Album"]] += r[i]["QTD"]
        else:
          purchase_album.update({r[i]["Album"] : r[i]["QTD"]})
  print(purchase_album)
  highest_album  = max(purchase_album, key=purchase_album.get)
  album_amount_sold = purchase_album[highest_album]
  print(f'''Most sold album of the dayhighest_album
Album: {highest_album}
Amount sold: {album_amount_sold}''')
def main_menu():
    account = input('''Welcome to Calabouço Discos
    Admin     [1]
    Client    [2]
    Exit Menu [3]
    ''')
    if account   == '1':
      admin_menu_store()        
    elif account == '2':      
      client_menu_store()
    elif account == '3':      
      print('See you later')
      quit()
    else:
      print('Invalid Option')
      main_menu()

def admin_menu_store():
  password = input('Password: ')
  match password:
    case '1234':
      print('''
  --------MENU--------
  Search Record               [1]
  Add new album               [2]
  Close Cashier               [3]
  Delete album from inventory [4]
  Return Main Menu            [5]
  ''')
      option = input()
      match option:
          case '1':
            search_record()
          case '2':
            inventory_store()
          case '3':
            close_cashier_store()
          case '4':
            delete_record_store()
          case '5': 
            print('Thank you for working with Calabouço Discos! See you later')
            main_menu()
          case _:
            admin_menu_store()
    case _:
      print('Invalid Password')
      main_menu()





def client_menu_store():
  print(''' Welcome to Calabouço Discos!
      --------MENU--------
      Search Record    [1]
      Return Main Menu [2]
      ''')
  option2 = input()
  match option2:
      case '1':
        search_record()
      case '2': 
        print('Thank you for shopping with Calabouço Discos! See you later')
        main_menu()
      case other :
        print('Invalid Option')
        client_menu_store()





main_menu()






#Solution version 1
# ALBUMS_ROCK = {
#   'Singer'      : [{'Album': '' , 'year': '', 'qnt': '', 'price' : ''}],
#   'bob dylan'   : [{'Album': 'time out of mind' , 'year': '1997', 'qnt': 2 , 'price': 30.00}],
#   'jon bon jovi': [{'Album': 'blaze of glory' , 'year': '1990', 'qnt':1 , 'price': 29.50}],
#   'the smiths'  : [{'Album': 'meat is murder' , 'year': '1985' , 'qnt': 4, 'price': 35.95}],
#   'kurt Cobain' : [{'Album': 'nevermind' , 'year': '1991' , 'qnt': 2, 'price': 25.00}]
# }

# ALBUMS_BLUES = {
#   'Singer'          : [{'Album': '' , 'year': '', 'qnt': '' , 'price' : ''}],
#   'buddy guy'       : [{'Album': 'living proof' , 'year': '2010', 'qnt': 1 , 'price' : 32.45}],
#   'b. b. king'      : [{'Album': 'live in cook county jail', 'year': '1968' , 'qnt': 3, 'price' : 45.00},{'Album': 'lucille', 'year': '1968' , 'qnt': 3, 'price' : 39.99}],
#   'john lee hooker' : [{'Album': 'aretha franklin', 'year': '1979' , 'qnt': 2, 'price' : 22.00}],
#   'aretha franklin' : [{'Album': 'i never loved a man the way i love you' ,'year': '1967' , 'qnt': 2, 'price' : 31.70}]}



# ALBUMS_MPB = {
#   'Singer'         : [{'Album': '' , 'year': '', 'qnt': '' , 'price' : '' }],
#   'novos baianos'  : [{'Album': 'acabou chorare' , 'year': '1972' , 'qnt': 1, 'price' : 22.00 }],
#   'elis regina'    : [{'Album': 'falso brilhante' , 'year': '1976' , 'qnt': 2, 'price' : 30.00 }],
#   'chico buarque'  : [{'Album': 'meus caros amigos' , 'year': '1976', 'qnt': 3, 'price' : 31.00}]
# }

# ALBUM_GENRE = {
#   1: {'Classic Rock' : ALBUMS_ROCK},
#   2: {'Blues'        : ALBUMS_BLUES},
#   3: {'MPB'          : ALBUMS_MPB}
# }

# client = [{'name':'','age': '','email':'', 'phone': ''},{'name':'Ana Paula','age': '23','email':'apm.hh@gmail.com', 'phone': '453255766'}]
# purchase = [{'genre':'','album': '','artist':'', 'price': 0, 'client': '','age': 0},{'genre':'MPB','album': 'como nossos pais','artist':'elis regina', 'price': 55.2, 'client': 'Ana Carla','age':33},{'genre':'Blues','album': 'lucille','artist':'b. b. king', 'price': 57, 'client': 'Ana Rosa','age':57},{'genre':'Blues','album': 'lucille','artist':'b. b. king', 'price': 57, 'client': 'Pedro Paulo','age':67},{'genre':'Classic Rock','album': 'Never again','artist':'The best', 'price': 30, 'client': 'Rodrigo Augusto','age':32},{'genre':'Classic Rock','album': 'SOAD','artist':'system of a down', 'price': 30, 'client': 'graca maria','age':70},{'genre':'MPB','album': 'lucille','artist':'novos baianos', 'price': 30, 'client': 'Bruno Martins','age':44},{'genre':'Blues','album': 'lucille','artist':'b. b. king', 'price': 30, 'client': 'Kyle Dumke','age':34},{'genre':'MPB','album': 'acabou chorare','artist':'caetano veloso', 'price': 30, 'client': 'Rodrigo Santana','age':45},{'genre':'Classic Rock','album': 'the dark side of the moon','artist':'pink floyd', 'price': 30, 'client': 'Paulo Assis','age':24},{'genre':'Classic Rock','album': 'lucille','artist':'b. b. king', 'price': 30, 'client': 'Ana Carolina','age':18},{'genre':'Classic Rock','album': 'new age','artist':'The smiths', 'price': 99, 'client': 'Ana Carolina','age':18}]

# def menu_store(cond):
#   while cond == True:
#     account = input('''Welcome to Calabouço Discos
#     Admin  [1]
#     Client [2]
#     ''')
#     if account == '1':
#       password = input('Password: ')
#       match password:
#         case '1234':
#           print('''
#       -------MENU-------
#       Search Record  [1]
#       Add new album  [2]
#       Close Cashier  [3]
#       Exit Menu      [4]
#       ''')
#           option = input()
#           match option:
#               case '1':
#                 find_album_store()
#               case '2':
#                 add_album_store()
#               case '3':
#                 close_cashier_store()
#               case '4': 
#                 print('Thank you for working with Calabouço Discos! See you later')
#                 cond = False
#                 break
#               case _:
#                 menu_store(cond)
#         case _:
#           print('Invalid Password')
#           menu_store(cond)
          
#     if account == '2':      
#       print(''' Welcome to Calabouço Discos!
#       -------MENU-------
#       Search Record  [1]
#       Exit Menu      [2]
#       ''')
#       option2 = input()
#       match option2:
#           case '1':
#             find_album_store()
#           case '2': 
#             print('Thank you for shopping with Calabouço Discos! See you later')
#             break
#           case _:
#             menu_store(cond)
#     else:
#       menu_store(cond)
  
# # menu_store(True)


      
# def calc_age_genre(genre_age):
#   count_genre = {'MPB':0,'Blues':0,'Classic Rock':0}
#   for x in genre_age:
#     if x == 'MPB':
#       count_genre['MPB'] += 1
#     elif x == 'Blues':
#       count_genre['Blues'] += 1
#     elif x == 'Classic Rock':
#       count_genre['Classic Rock'] += 1

#   #Here what is happening is that he runs all the values(get) and for the highest(max) I get the key?
#   count = max(count_genre, key=count_genre.get)
#   repeats = []
#   max_repeats = 0
#   for k,v in count_genre.items():
#     if count_genre[count] == v:
#         max_repeats +=1
#         repeats.append(k)
#   if max_repeats == 1:     
#       return repeats[0]
#   if max_repeats == 2:     
#       return f'{repeats[0]} and {repeats[1]}'
#   if max_repeats == 3:     
#       return 'No preference for this age group'

    
# def close_cashier_store():
#   close = input('Are you sure you want to close the Cashier? [y/n]')
#   if close == 'y':
#     print('A closing report is being wrapped up. This might take a few seconds.')
#     purchases = []
#     ages = []
#     albums = []
#     genres = []
#     genre_age_D = []
#     genre_age_C =[]
#     genre_age_B = []
#     genre_age_A = []
#     total_sales = len(purchase)
#     for i in range(len(purchase)):
#       purchases.append(purchase[i]['price'])
#       ages.append(purchase[i]['age'])
#       albums.append(purchase[i]['album'])
#       genres.append(purchase[i]['genre'])

#     for i in range(len(genres)):
#       if ages[i] > 55:
#         genre_age_D.append(genres[i])
#       elif ages[i] > 35:
#         genre_age_C.append(genres[i])
#       elif ages[i] > 25:
#         genre_age_B.append(genres[i])
#       elif 18 <= ages[i] < 25: 
#         genre_age_A.append(genres[i])
    
#     d = calc_age_genre(genre_age_D)
#     c = calc_age_genre(genre_age_C)
#     b = calc_age_genre(genre_age_B)
#     a = calc_age_genre(genre_age_A)  
    
#     profit = sum(purchases)
#     album_search = max(albums,key=albums.count)
#     for k,v in ALBUM_GENRE.items():
#       #Assign the music genre to be searched
#       genre  = list(v)
#       info   = (ALBUM_GENRE[k][genre[0]])
#       for k1,v1 in info.items():
#         for i in range(len(v1)):
#           if album_search ==  v1[i]['Album']:
#             genre_album = genre[0]
#             album  = v1[i]['Album']
#             Artist = k1
#             Year   = v1[i]['year']
#             Price  = v1[i]['price']
#             Qtd    = v1[i]['qnt']
            
#     high_client,high_price = highest_sell_store()
    
        
#     print('----------Report-----------')
#     print('------Purchase Record------')
#     for i in range(len(purchase)):
#         print(f"Genre         : {purchase[i]['genre']}")
#         print(f"Album         : {purchase[i]['album']}")
#         print(f"Artist        : {purchase[i]['artist']}")
#         print(f"Price         : ${purchase[i]['price']}")
#         print(f"Client        : {purchase[i]['client']}")
#         print(f"Age           : {purchase[i]['age']}")
#         print(""" -------------------------- 
        
#         """)

#     print(f'Total Sales    : {total_sales}')
#     print(f'Total CashIn   : ${profit}')
#     print(""" -------------------------- 
            
#             """)
#     print(f'''Highest sale  : ${high_price} spent by {high_client}:
#     ''')
#     j,h = highest_sell_store()
#     for i in range(len(purchase)):
#       if j == purchase[i]['client']:
#         print(f"Genre         : {purchase[i]['genre']}")
#         print(f"Album         : {purchase[i]['album']}")
#         print(f"Artist        : {purchase[i]['artist']}")
#         print(f"Price         : ${purchase[i]['price']}")
#         print(f"Client        : {purchase[i]['client']}")
#         print(f"Age           : {purchase[i]['age']}")
#         print(""" -------------------------- 
            
#             """)
#     print(f'''Most sold album: 
#     Genre  : {genre_album}
#     Album  : {album}
#     Artist : {Artist}
#     Year   : {Year}
#     Price  : ${Price}
#     Quantity Available in stock : {Qtd}''')
#     print(""" -------------------------- 
            
#             """)
    
#     print(f'''Genre most sold per age range:
#     [18-25] : {a}
#     [25-35] : {b}
#     [35-55] : {c}
#     [55+]   : {d}''')
#     print(""" -------------------------- 
            
#             """)
    
#     print('''
#     ''')
#     print('See you tomorrow!')




# def get_info_inventory_store():
#   singer = input('Artist name: ').lower()
#   album  = input('Album: ').lower()
#   year   = input('Year launched: ').lower()
#   while True:
#     try:
#       qtd    = int(input('Number of albums: '))
#       price  = float(input('Price: '))
#       break
#     except:
#       print('Invalid Option!')
  
#   return singer,[{'Album':album , 'year': year, 'qtd' : qtd , 'price' : price}]

# # # # # Function to add albums to inventory:

# def add_album_store():
#       try:
#         genre = int(input('''Genre:
# [1] Classic Rock
# [2] Blues
# [3] MPB
#         '''))
#         if genre == 1:
#           singer,info_list = get_info_inventory_store()
          
#           find    = ALBUMS_ROCK.get(singer,0)
#           if find == 0:
#             ALBUMS_ROCK[singer] = info_list
#           else:
#             ALBUMS_ROCK[singer].update(info_list) 
#           print(ALBUMS_ROCK)
        
#         elif genre == 2:
#           singer,info_list = get_info_inventory_store()
          
#           find    = ALBUMS_BLUES.get(singer,0)
#           if find == 0:
#             ALBUMS_BLUES[singer] = info_list
#           else:
#             ALBUMS_BLUES[singer].update(info_list) 
#           print(ALBUMS_ROCK)
           
#         elif genre == 3:
#           singer,info_list = get_info_inventory_store()
          
#           find    = ALBUMS_MPB.get(singer,0)
#           if find == 0:
#             ALBUMS_MPB[singer] = info_list
#           else:
#             ALBUMS_MPB[singer].update(info_list) 
#           print(ALBUMS_ROCK)
#         else:
#           print('Invalid Option')

#         while True:
#           print('''
          
# --------MENU---------
# Add another album [1]
# Main Menu         [2]
#           ''')     
#           answer = input()
#           match answer:
#             case '1':
#               add_album_store()
#               break
#             case '2':
#               menu_store(True)
#               break
#             case _:
#               print('Invalid option')
#               continue
#       except:
#         print('Invalid Option')
#         add_album_store()
        

# def print_genre_store():
#   try:  
#     genre = int(input('''Genre:
#     [1] Classic Rock
#     [2] Blues
#     [3] MPB
#             '''))
#     if genre   == 1:
#       for k,v in ALBUMS_ROCK.items():
#         print(k)
#         for i in range(len(v)):
#           print(f'''Album  : {v[i]['Album']}
# Year   : {v[i]['year']}
# Price  : {v[i]['price']}
# Quantity Available : {v[i]['qnt']}
#        ''')
#     elif genre == 2:
#       for k,v in ALBUMS_BLUES.items():
#         print(k)
#         for i in range(len(v)):
#           print(f'''Album  : {v[i]['Album']}
# Year   : {v[i]['year']}
# Price  : {v[i]['price']}
# Quantity Available : {v[i]['qnt']}
#        ''')
#     elif genre == 3:
#       for k,v in ALBUMS_MPB.items():
#         print(k)
#         for i in range(len(v)):
#           print(f'''Album  : {v[i]['Album']}
# Year   : {v[i]['year']}
# Price  : {v[i]['price']}
# Quantity Available : {v[i]['qnt']}
#        ''')
#   except:
#       print('Invalid Option.')
#       print_genre_store()
    
#   while True:  
#     print(''' --------Menu--------
#   [1] Purchase album
#   [2] Search another genre
#   [3] Main Menu
#   ''')
#     answer = input()
#     if   answer   == '1':
#       album_search = input('Record Album Name: ')
#       purchase_album_store(album_search)
#     elif answer   == '2':
#       print_genre_store()
#     elif answer   == '3':
#       print('We are taking you back to the Main Menu')
#       print('''
#       .
#       .
#       .
#       ''')
#       menu_store(True)
#     else:
#       print('Invalid Option')
#       continue



    
# # print_genre_store()

# def find_album_store():
#     try:
#       type = int(input('''Find by:
#     [1] Genre
#     [2] Artist
#     [3] Album
#     '''))
#       if   type == 1:
#         print_genre_store()
#       elif type == 2:
#         print_artist_store()
#       elif type == 3:
#         print_album_store()
#       else:
#         print('Invalid Option')
#         find_album_store()
#     except:
#       print('Invalid Option')


# def print_artist_store():
#   artist = input('Artist: ')
#   for k,v in ALBUM_GENRE.items():
#     genre  = list(v)
#     info   = (ALBUM_GENRE[k][genre[0]])
#     singer = list(info.keys())
#     if artist in singer:
#       print('Artist Found.')
#       print(f'Artist : {artist}')
#       print(f'Genre  : {genre[0]}')
#       print('Albums Available for Purchase :')
#       info_artist = ALBUM_GENRE[k][genre[0]][artist]
#       for i in range(len(info_artist)):
#         print(f'''Album  : {info_artist[i]['Album']}
# Year   : {info_artist[i]['year']}
# Price  : {info_artist[i]['price']}
# Quantity Available : {info_artist[i]['qnt']}
#       ''')
#         while True:
#             print(''' --------Menu--------
#   [1] Purchase album
#   [2] Search another artist
#   [3] Main Menu
#   ''')
#             answer = input()
#             if   answer   == '1':
#               album_search = input('Record Album Name: ')
#               purchase_album_store(album_search)
#             elif answer   == '2':
#               print_genre_store()
#             elif answer   == '3':
#               print('We are taking you back to the Main Menu')
#               print('''
#               .
#               .
#               .
#               ''')
#               menu_store(True)
#             else:
#               print('Invalid Option')
#               continue


# def print_album_store():
#   album_search = input('Record Album Name: ')
#   for k,v in ALBUM_GENRE.items():
#     #Assign the music genre to be searched
#     genre  = list(v)
#     info   = (ALBUM_GENRE[k][genre[0]])
#     for k1,v1 in info.items():
#       for i in range(len(v1)):
#         if album_search ==  v1[i]['Album']:
#           genre_album = genre[0]
#           album  = v1[i]['Album']
#           Artist = k1
#           Year   = v1[i]['year']
#           Price  = v1[i]['price']
#           Qtd    = v1[i]['qnt']
#           print(f''' Record Found! 
#   Genre  : {genre_album}
#   Album  : {album}
#   Artist : {Artist}
#   Year   : {Year}
#   Price  : ${Price}
#   Quantity Available : {Qtd}
#         ''')
#           while True:
#             print(''' --------Menu--------
#   [1] Purchase album
#   [2] Search another album
#   [3] Main Menu
#   ''')
#             answer = input()
#             if   answer   == '1':
#               purchase_album_store(album_search)
#             elif answer   == '2':
#               print_album_store()
#             elif answer   == '3':
#               print('We are taking you back to the Main Menu')
#               print('''
#               ...
#               ''')
#               menu_store(True)
#             else:
#               print('Invalid Option')
#               continue


# def purchase_album_store(album):
#   print('Please add your information below to proceed with the purchase: ')
#   name        = input('Full Name: ')
#   birth_day   = input('Birthday day: ')
#   birth_month = input('Birthday month: ')
#   birth_year  = int(input('Birthday year: '))
#   email       = input('Email: ')
#   phone       = input('Phone: ')
#   age         = 2023 - birth_year
#   while True:
#     check       = input(f'''Is the information below correct (y/n):
#     Name     : {name}
#     Birthday : {birth_month}/{birth_day}/{birth_year}
#     Email    : {email}
#     Phone    : {phone}
#     ''').lower()
#     if check != 'y' and check != 'n':
#       print('Invalid Option')
#       continue
#     elif check == 'n':
#       purchase_album_store(album)
#     elif check == 'y':
#       print('Please confirm the purchase details below: ') 
#       for k,v in ALBUM_GENRE.items():
#         #Assign the music genre to be searched
#         genre  = list(v)
#         info   = (ALBUM_GENRE[k][genre[0]])
#         for k1,v1 in info.items():
#           for i in range(len(v1)):
#             if album ==  v1[i]['Album']:
#                 print(f''' 
#         Genre  : {genre[0]}
#         Album  : {v1[i]['Album']}
#         Artist : {k1}
#         Year   : {v1[i]['year']}
#         Price  : ${v1[i]['price']}''')
#       test = 1
#       while test == 1:
#         CONFIRM = input('''Do you want to proceed with the purchase? (y/n)
#         ''')
#         if CONFIRM!= 'y' and CONFIRM != 'n':
#           print('Invalid Option')
#           continue
#         elif CONFIRM == 'n':
#           print('Returning to Main Menu')
#           print('''
#           .
#           .
#           .
#           ''')
#           menu_store(True)
#         elif CONFIRM == 'y':
#           v1[i]['qnt'] -= 1
#           if v1[i]['qnt'] < 1:
#             v1[i]['qnt'] = 'Out of Stock'
#           register_client(name,age,email,phone)
#           register_purchase(genre,album,k1,v1[i]['price'],name,age)
#           print('Purchase Completed Succesfully')
#           print(f'A confirmation email will be sent to {email}')
#           print('Thanks for shopping with us!')
#           print('Returning to Main Menu')
#           print('''
#           .
#           .
#           .
#           ''')
#           menu_store(True)
  
# def register_client(name,age,email,phone):
#   find = client.get(name,0) 
#   if find == 0:
#     client.append({'name':name,'age':age,'email': email, 'phone': phone})
#   return True

# def register_purchase(genre,album,artist,price,client,age):
#     purchase.append({'genre':genre,'album':album,'artist': artist, 'price': 0, 'client': client, 'age' : age})


# high_purchase = {}
# def highest_sell_store():
#   for i in range(len(purchase)):
#     name = purchase[i]['client']
#     money_spent = purchase[i]['price']
#     if name in high_purchase:
#       high_purchase[name] += money_spent
#     else:
#       high_purchase[name] = money_spent
#   highest = max(high_purchase,key=high_purchase.get)
#   high_price = high_purchase[highest]
#   return highest, high_price
  



# # def menu_admin():
# # def menu_client():
# menu_store(True)
